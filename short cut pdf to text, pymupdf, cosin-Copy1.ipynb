# %%
import pandas as pd
import os
import arxiv

import urllib
from sklearn.metrics.pairwise import cosine_similarity
import fitz
import tensorflow_hub as hub
import numpy as np

# %%
from function import *

# %%
import time

# %%
#use tranfer learning
#takes longer to load than dan
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")

# %%
# USE dan
# embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
table = pd.read_csv('combined_table.csv').drop('Unnamed: 0', axis =1)
# test = table.head() #for testing purposes
# Out:
# C:\Users\20193635\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# #for testing purposes
# tab = prepare_table(test) 
# tab

# %%
# start = time.time()
# not_sample, sample = pdf_sim(embed, tab,max_iter = 2)
# end = time.time()
# print("Time taken:            {:.3f}s".format(end - start))

# %%
# sample.loc[:,['title','Succes', 'w_Anth', 'w_Arxiv', 'w_both', 'pages_Anth', 'pages_Arxiv', 'cosine', 'len_blocks', 'len_Anth', 'len_Arxiv', 'len_both', 'ref_Anth', 'ref_Arxiv', 'Jaccard' ]]
# Out:
#                                                title  Succes  w_Anth  w_Arxiv  \
# 4  Memes in the Wild: Assessing the Generalizabil...     1.0  4865.0   4835.0
# 3  HateBERT: Retraining BERT for Abusive Language...     1.0  4919.0   3758.0
#
#    w_both  pages_Anth  pages_Arxiv    cosine  len_blocks  len_Anth  len_Arxiv  \
# 4  4794.0        10.0         10.0  0.999445       148.0     148.0      148.0
# 3    44.0         9.0          8.0  0.908775         8.0       8.0        8.0
#
#    len_both  ref_Anth  ref_Arxiv   Jaccard
# 4     148.0      87.0       82.0  0.989873
# 3       8.0      65.0       46.0  0.426143

# %%
# sample
# Out:
#                                                title  year   month  \
# 4  Memes in the Wild: Assessing the Generalizabil...  2021  August
# 3  HateBERT: Retraining BERT for Abusive Language...  2021  August
#
#                                       url  \
# 4  https://aclanthology.org/2021.woah-1.4
# 3  https://aclanthology.org/2021.woah-1.3
#
#                                          title_Arxiv  \
# 4  Memes in the Wild: Assessing the Generalizabil...
# 3  HateBERT: Retraining BERT for Abusive Language...
#
#                        pdf_url_Arxiv            published_Arxiv  \
# 4  http://arxiv.org/pdf/2107.04313v1  2021-07-09 09:04:05+00:00
# 3  http://arxiv.org/pdf/2010.12472v1  2020-10-23 15:14:14+00:00
#
#                         result_Arxiv  Succes  w_Anth  ...  pages_Arxiv  cosin  \
# 4  http://arxiv.org/abs/2107.04313v1     1.0  4865.0  ...         10.0    NaN
# 3  http://arxiv.org/abs/2010.12472v2     1.0  4919.0  ...          8.0    NaN
#
# ...

# %%
table_pred = prepare_table(table)

# %%
start = time.time()
not_sample, sample = pdf_sim(embed, table_pred,max_iter = 1000)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# ...

# %%
print("Time taken:            {:.3f}s".format(end - start))  #376 seconds for 100 papers
# Out:
# Time taken:            37179.749s

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
sample.head()
# Out:
#                                                    title  year  \
# 10592  Pre-training for Abstractive Document Summariz...  2020
# 9854   Pretrained Language Models for Dialogue Genera...  2020
# 2432   MobIE: A German Dataset for Named Entity Recog...  2021
# 20073  Multi-Relational Question Answering from Narra...  2018
# 17560  PubMedQA: A Dataset for Biomedical Research Qu...  2019
#
#                 month                                              url  \
# 10592        November     https://aclanthology.org/2020.emnlp-main.297
# 9854         November  https://aclanthology.org/2020.findings-emnlp.81
# 2432   6--9 September       https://aclanthology.org/2021.konvens-1.22
# 20073            July                https://aclanthology.org/P18-1077
# 17560        November                https://aclanthology.org/D19-1259
#
#                                              title_Arxiv  \
# 10592  Pre-training for Abstractive Document Summariz...
# ...

# %% [markdown]
# # Store and load tables/csv of sample and not sample

# %%
#reading csv
# sample = pd.read_csv('sample.csv',index_col='Unnamed: 0')
# not_sample = pd.read_csv('not_sample.csv',index_col='Unnamed: 0')

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Exception found some error
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            22160.884s

# %% [markdown]
# # Start iterations

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            683.217s

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            683.217s

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            683.217s

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            683.217s

# %%
start = time.time()
not_sample, sample = pdf_sim(embed=embed, tab_old = not_sample, result=sample,max_iter = 1000, r_state=2)
end = time.time()
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# Exception found some error
# ...

# %%
# save csv
sample.to_csv('sample.csv')
not_sample.to_csv('not_sample.csv')

# %%
print("Time taken:            {:.3f}s".format(end - start))
# Out:
# Time taken:            683.217s

# %% [markdown]
# # save tables

# %%
# save csv
# sample.to_csv('sample.csv')
# not_sample.to_csv('not_sample.csv')

# %% [markdown]
# # see tables

# %%
table['title_Arxiv']
# Out:
# array(['NF',
#        'Modeling Profanity and Hate Speech in Social Media with Semantic Subspaces',
#        'HateBERT: Retraining BERT for Abusive Language Detection in English',
#        ...,
#        'Temporal Analysis of Language through Neural Language Models',
#        'A Deep Architecture for Semantic Parsing', nan], dtype=object)

# %%
len(table[table['title_Arxiv']=='NF']), len(table[table['title_Arxiv']=='skipping'])
# Out:
# (24448, 0)

# %%
# 24448+55031
63916 - 55031,30603 +24448, 63916 -30603
# 55031,
# 30603 +24448
# Out:
# (8885, 55051, 33313)

# %%
# table[table['published_Arxiv'].isna()][table['title_Arxiv'].isna()==False]

# %%
table.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18404/3544758825.py in <module>
# ----> 1 table.sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# ...

# %%
table.isna().sum()
# Out:
# ISBN               62513
# address              741
# booktitle           2491
# doi                36791
# journal            63243
# language           62533
# month                  0
# note               63723
# number             63451
# pages               9870
# publisher           3903
# title                  0
# url                    0
# volume             63451
# year                   0
# clean                  0
# title_Arxiv        30603
# pdf_url_Arxiv      55031
# published_Arxiv    55031
# result_Arxiv       55031
# dtype: int64

# %%
not_sample
# Out:
#                                                    title  year   month  \
# 2      Modeling Profanity and Hate Speech in Social M...  2021  August
# 3      HateBERT: Retraining BERT for Abusive Language...  2021  August
# 4      Memes in the Wild: Assessing the Generalizabil...  2021  August
# 5      Measuring and Improving Model-Moderator Collab...  2021  August
# 10     Improving Counterfactual Generation for Fair H...  2021  August
# ...                                                  ...   ...     ...
# 33180  Credibility Adjusted Term Frequency: A Supervi...  2014    June
# 33183  Improving Agreement and Disagreement Identific...  2014    June
# 33201            Finding Eyewitness Tweets During Crises  2014    June
# 33208  Temporal Analysis of Language through Neural L...  2014    June
# 33217           A Deep Architecture for Semantic Parsing  2014    June
#
#                                            url  \
# 2       https://aclanthology.org/2021.woah-1.2
# ...

# %%
sample
# Out:
#                                                    title  year  \
# 10592  Pre-training for Abstractive Document Summariz...  2020
# 9854   Pretrained Language Models for Dialogue Genera...  2020
# 2432   MobIE: A German Dataset for Named Entity Recog...  2021
# 20073  Multi-Relational Question Answering from Narra...  2018
# 17560  PubMedQA: A Dataset for Biomedical Research Qu...  2019
# ...                                                  ...   ...
# 2523   A Transition-based Parser for Unscoped Episodi...  2021
# 7811   On the Choice of Auxiliary Languages for Impro...  2020
# 21190  Annotating High-Level Structures of Short Stor...  2018
# 17562  Answering Complex Open-domain Questions Throug...  2019
# 18233  Japanese Sentiment Classification using a Tree...  2018
#
#                  month                                              url  \
# 10592         November     https://aclanthology.org/2020.emnlp-main.297
# ...

# %%
sample.isna().sum()
# Out:
# title              0
# year               0
# month              0
# url                0
# title_Arxiv        0
# pdf_url_Arxiv      0
# published_Arxiv    0
# result_Arxiv       0
# Succes             0
# w_Anth             0
# w_Arxiv            0
# w_both             0
# pages_Anth         0
# pages_Arxiv        0
# cosin              0
# len_blocks         0
# len_Anth           0
# len_Arxiv          0
# len_both           0
# dtype: int64

# %%
sample.tail(5)
# Out:
#                                                    title  year  \
# 2523   A Transition-based Parser for Unscoped Episodi...  2021
# 7811   On the Choice of Auxiliary Languages for Impro...  2020
# 21190  Annotating High-Level Structures of Short Stor...  2018
# 17562  Answering Complex Open-domain Questions Throug...  2019
# 18233  Japanese Sentiment Classification using a Tree...  2018
#
#                  month                                          url  \
# 2523              June      https://aclanthology.org/2021.iwcs-1.18
# 7811              July  https://aclanthology.org/2020.repl4nlp-1.13
# 21190              May            https://aclanthology.org/L18-1520
# 17562         November            https://aclanthology.org/D19-1261
# 18233  1{--}3 December            https://aclanthology.org/Y18-1054
#
#                                              title_Arxiv  \
# 2523   A Transition-based Parser for Unscoped Episodi...
# 7811   On the Choice of Auxiliary Languages for Impro...
# ...
