# %%
import pandas as pd
import arxiv
import pandas as pd
import requests
import urllib
import numpy as np

# %%
table = pd.read_csv('combined_table.csv',index_col='Unnamed: 0')
# Out:
# C:\Users\20193635\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,4,5,8,17,18,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
table
# Out:
#       ISBN                                address  \
# 0      NaN                                 Online
# 1      NaN                                 Online
# 2      NaN                                 Online
# 3      NaN                                 Online
# 4      NaN                                 Online
# ...    ...                                    ...
# 74515  NaN  Massachusetts Institute of Technology
# 74516  NaN  Massachusetts Institute of Technology
# 74517  NaN  Massachusetts Institute of Technology
# 74518  NaN  Massachusetts Institute of Technology
# 74519  NaN  Massachusetts Institute of Technology
#
#                                                booktitle  \
# 0                                                    NaN
# 1      Proceedings of the 5th Workshop on Online Abus...
# 2      Proceedings of the 5th Workshop on Online Abus...
# 3      Proceedings of the 5th Workshop on Online Abus...
# 4      Proceedings of the 5th Workshop on Online Abus...
# ...

# %%
len(table) - table['title_Arxiv'].isna().sum()
# Out:
# 6201
