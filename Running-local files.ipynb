# %%
import pandas as pd
import os
import arxiv

import urllib
from sklearn.metrics.pairwise import cosine_similarity
import fitz
import tensorflow_hub as hub
import numpy as np

# %%
from function import *

# %%
import time
import matplotlib as plt

# %%
import re
import sys

# %%
#use tranfer learning
#takes longer to load than dan
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")

# %%
table = pd.read_csv('combined_table.csv').drop('Unnamed: 0', axis =1)
# test = table.head() #for testing purposes
# Out:
# C:\Users\20193635\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def get_text(doc):
    blocks = []
    for page in doc.pages():
        b_p = page.get_text('blocks')
        for b in b_p:
            if b[6] == 0: #only text not metadata pictures.
                blocks.append(b[4])

# %%
type((np.NaN))
# Out:
# float

# %%
print(type(papers['Anth_name'].iloc[0])==type(float()))
# Out:
# True

# %%
def pdf_similarity_loc(embed, tab_old, result=None, max_iter=1, r_state = 2):
    """
    Wanted statistics?: number of words, similarity, number of pages, percentage of words exactly the same,
    in = table
    """ 
    # for each random row in table, replace=False all rows only sampled once
    sample = tab_old.sample(n=max_iter, replace=False, random_state=r_state)
    not_sample = tab_old.drop(sample.index)
    
    #download two papers from table
    loc_name_Arxiv = 'pdf Arxiv/'
    loc_name_Anth = 'pdf Anth/'
    
    #needs to be changed
    sample[['Succes', 'w_Anth', 'w_Arxiv', 'pages_Anth', 'pages_Arxiv', 'cosine', 'ref_Anth', 'ref_Arxiv', 'Jaccard' ]] =np.nan
    
    
    for index,series in sample.iterrows():
        sample.loc[[index],['Succes']]=0

#         if True:
        #open paper in jupiter/blocks
        try: #sometimes download not available. Then download works but does not give a good pdf so reading does not work
#             urllib.request.urlretrieve(series['pdf_url_Arxiv'], loc_name_Arxiv)
            if type(series['Anth_name'])==type(float()):
                name_Anth = loc_name_Anth+'Anth-'+series['clean']+'.pdf'
                urllib.request.urlretrieve(series['url']+'.pdf', name_Anth)
                series.loc['Anth_name'] = 'Anth-'+series['clean']+'.pdf'
#                 doc_Anth = fitz.open(loc_name_Anth+series['Anth_name'])
                doc_Anth = fitz.open(name_Anth)
            else:
                doc_Anth = fitz.open(loc_name_Anth+series['Anth_name'])
            print('start with two papers')
            doc_Arxiv = fitz.open(loc_name_Arxiv+series['Arxiv_name'])
            

            b_Anth = get_blocks(doc_Anth)
            b_Arxiv = get_blocks(doc_Arxiv)
#             print(doc_Anth)
#             print(doc_Arxiv)
            
            #try removing sidebar from arxiv
            # if we DO find something
            if [i for i, x in enumerate(b_Arxiv) if x.find('arXiv:')>= 0] !=[]:
                i_sidebar = [i for i, x in enumerate(b_Arxiv) if x.find('arXiv:')>= 0][0]
                if len(b_Arxiv[i_sidebar])< 50: #dont remove references by accident, normal sidebar is length 41
                    x = b_Arxiv.pop(i_sidebar)
#                     print(x)
            
            #remove footnote from anthology (could/did not remove pagenumbers)
            if b_Anth[0][0:18] == 'Proceedings of the' and len(b_Anth[0])<150:
                b_Anth=b_Anth[1:]

#             elem_both_list = set()
            elem_both_list = set(b_Anth)&set(b_Arxiv)
            #sometimes same occurs twice in paper then remove this from elem_both_list
            dup = [x for x in elem_both_list if b_Anth.count(x)>1]
            dup = set(dup + [x for x in elem_both_list if b_Anth.count(x)>1])
            for el in dup:
                elem_both_list.remove(el)
                
        
            #number of citations
            if [i for i, x in enumerate(b_Anth) if x.find('References')>= 0] ==[]:
                ref_Anth='NF'
                ref_Arxiv='NF'
            elif [i for i, x in enumerate(b_Anth) if x.find('References')>= 0] ==[]:
                ref_Anth='NF'
                ref_Arxiv='NF'
            else:              
                start_ref_Anth = [i for i, x in enumerate(b_Anth) if x.find('References')>= 0][0]
                start_ref_Arxiv = [i for i, x in enumerate(b_Arxiv) if x.find('References')>= 0][0]
                
  
                amount_pattern = r'(?:[1][89][0-9]{2}[^0-9]|[2][0][012][0-9][^0-9])'
                amount_expr = re.compile(amount_pattern, re.IGNORECASE)
                l = []
                for i in b_Anth[start_ref_Anth:]:
                    l+=(amount_expr.findall(i))
                ref_Anth=len(l)
                l = []
                for i in b_Arxiv[start_ref_Anth:]:
                    l+=(amount_expr.findall(i))
                ref_Arxiv=len(l)
    
#                 ref_Anth,ref_Arxiv = max([len(b_Anth[start_ref_Anth:]),len(b_Arxiv[start_ref_Arxiv:])],
#                                          [sum([x.count('[') for x in b_Anth[start_ref_Anth:]]),
#                                           sum([x.count('[') for x in b_Arxiv[start_ref_Arxiv:]])])
                
    
            #similarity
            cosine_avg, w_Anth, w_Arxiv, jacc = similarity_loc(b_Anth,b_Arxiv,embedding=embed)
            
            # add statistics to table 'sample'
            sample.loc[[index],['cosine_avg', 'w_Anth', 'w_Arxiv', 'ref_Anth', 'ref_Arxiv', 'Jaccard']]= cosine_avg, w_Anth, w_Arxiv, ref_Anth, ref_Arxiv, jacc
            sample.loc[[index],['pages_Anth', 'pages_Arxiv']] = [doc_Anth.page_count, doc_Arxiv.page_count]
            
            sample.loc[[index],['Succes']]=1
            

        except: #error with downloading 
            print('Exception found some error')
            next 
              
        time.sleep(3)
        
    #end loop
    # join tables
    if type(result) ==pd.DataFrame:
        sample = sample.merge(result,how='outer')
    return not_sample, sample

# %%
def similarity_loc(anth, arxiv, embedding):
#     print('start sim')
    anth = [clean_n(x) for x in anth]
    arxiv = [clean_n(x) for x in arxiv]
    
    w_anth = " ".join(anth).split()
    w_arxiv = " ".join(arxiv).split()
    
    set_Anth = set(w_anth)
    set_Arxiv = set(w_arxiv)
    
    # jacc = Intersection/Union
    jacc = len(set_Anth & set_Arxiv)/len(set_Anth | set_Arxiv)
    
    df = pd.DataFrame()
    df['Anth'] = [" ".join(list(x)) for x in np.array_split(np.array(w_anth),20)]
    df['Arxiv'] = [" ".join(list(x)) for x in np.array_split(np.array(w_arxiv),20)]
    
    df['words Anth'] = df['Anth'].apply(lambda x: len(x.split()))
    df['words Arxiv'] = df['Arxiv'].apply(lambda x: len(x.split()))
    
    df['cosine'] = df.apply(lambda x:cosine_similarity(embedding([x.Anth]),embedding([x.Arxiv])), axis=1)
    df['cosine'] = df['cosine'].astype(float)

#     display(df)
#     df.tolatex()

    #nr of words per paper
    nr_w_Anth = sum(df['words Anth'])
    nr_w_Arxiv = sum(df['words Arxiv'])

    cosine_avg = round(np.average(df['cosine']),6)
    
    return cosine_avg, nr_w_Anth, nr_w_Arxiv, jacc

# %%
import glob

# %%
Anth_list = []
for name in glob.glob(r'C:\Users\20193635\OneDrive - TU Eindhoven\Documents\Data Science Year 3\BEP\pdf Anth/*.pdf'): 
    Anth_list.append(name.split("pdf Anth\\")[-1])

# %%
Arxiv_list = []
for name in glob.glob(r'C:\Users\20193635\OneDrive - TU Eindhoven\Documents\Data Science Year 3\BEP\pdf Arxiv/*.pdf'): 
    Arxiv_list.append((name.split("pdf Arxiv\\")[-1]))

# %%
t=table.copy()
t = t.dropna(subset=['pdf_url_Arxiv'])
t['idv1']=t['pdf_url_Arxiv'].apply(only_first).apply(lambda x: x[-12:])

# %%
t.head()
# Out:
#    ISBN address                                          booktitle  \
# 2   NaN  Online  Proceedings of the 5th Workshop on Online Abus...
# 3   NaN  Online  Proceedings of the 5th Workshop on Online Abus...
# 4   NaN  Online  Proceedings of the 5th Workshop on Online Abus...
# 5   NaN  Online  Proceedings of the 5th Workshop on Online Abus...
# 10  NaN  Online  Proceedings of the 5th Workshop on Online Abus...
#
#                            doi journal language   month note  number    pages  \
# 2    10.18653/v1/2021.woah-1.2     NaN      NaN  August  NaN     NaN    6--16
# 3    10.18653/v1/2021.woah-1.3     NaN      NaN  August  NaN     NaN   17--25
# 4    10.18653/v1/2021.woah-1.4     NaN      NaN  August  NaN     NaN   26--35
# 5    10.18653/v1/2021.woah-1.5     NaN      NaN  August  NaN     NaN   36--53
# 10  10.18653/v1/2021.woah-1.10     NaN      NaN  August  NaN     NaN  92--101
#
#     ...                                              title  \
# 2   ...  Modeling Profanity and Hate Speech in Social M...
# 3   ...  HateBERT: Retraining BERT for Abusive Language...
# 4   ...  Memes in the Wild: Assessing the Generalizabil...
# 5   ...  Measuring and Improving Model-Moderator Collab...
# 10  ...  Improving Counterfactual Generation for Fair H...
#
#                                         url volume  year  \
# 2    https://aclanthology.org/2021.woah-1.2    NaN  2021
# 3    https://aclanthology.org/2021.woah-1.3    NaN  2021
# 4    https://aclanthology.org/2021.woah-1.4    NaN  2021
# 5    https://aclanthology.org/2021.woah-1.5    NaN  2021
# 10  https://aclanthology.org/2021.woah-1.10    NaN  2021
#
#                                                 clean  \
# 2   Modeling Profanity and Hate Speech in Social M...
# 3   HateBERT  Retraining BERT for Abusive Language...
# 4   Memes in the Wild  Assessing the Generalizabil...
# 5   Measuring and Improving Model Moderator Collab...
# 10  Improving Counterfactual Generation for Fair H...
#
#                                           title_Arxiv  \
# 2   Modeling Profanity and Hate Speech in Social M...
# 3   HateBERT: Retraining BERT for Abusive Language...
# 4   Memes in the Wild: Assessing the Generalizabil...
# 5   Measuring and Improving Model-Moderator Collab...
# 10  Improving Counterfactual Generation for Fair H...
#
#                         pdf_url_Arxiv            published_Arxiv  \
# 2   http://arxiv.org/pdf/2106.07505v2  2021-06-14 15:34:37+00:00
# 3   http://arxiv.org/pdf/2010.12472v2  2020-10-23 15:14:14+00:00
# 4   http://arxiv.org/pdf/2107.04313v1  2021-07-09 09:04:05+00:00
# 5   http://arxiv.org/pdf/2107.04212v1  2021-07-09 05:07:25+00:00
# 10  http://arxiv.org/pdf/2108.01721v1  2021-08-03 19:47:27+00:00
#
#                          result_Arxiv          idv1
# 2   http://arxiv.org/abs/2106.07505v2  2106.07505v1
# 3   http://arxiv.org/abs/2010.12472v2  2010.12472v1
# 4   http://arxiv.org/abs/2107.04313v1  2107.04313v1
# 5   http://arxiv.org/abs/2107.04212v1  2107.04212v1
# 10  http://arxiv.org/abs/2108.01721v1  2108.01721v1
#
# [5 rows x 21 columns]

# %%
df_anth = pd.DataFrame()
df_anth['Anth_name'] = Anth_list
df_anth['title'] = df_anth['Anth_name'].apply(lambda x: x[5:-4])
df_anth = df_anth.drop_duplicates(subset= ['title'], keep ='last')
# df_anth

df_Arxiv = pd.DataFrame()
df_Arxiv['Arxiv_name'] = Arxiv_list
df_Arxiv['id'] = df_Arxiv['Arxiv_name'].apply(lambda x: x[:12])
df_Arxiv['idv1'] = df_Arxiv['id'].apply(lambda x: x[:-1]+'1')
df_Arxiv['version'] = df_Arxiv['id'].apply(lambda x: x[-1])
t2 = t.merge(df_Arxiv, on='idv1')
papers = t2.merge(df_anth, on='title', how='left')

# %%
len(papers), papers.isna().sum()
# Out:
# (150,
#  ISBN               149
#  address              0
#  booktitle            0
#  doi                 13
#  journal            150
#  language           149
#  month                0
#  note               150
#  number             150
#  pages                1
#  publisher            0
#  title                0
#  url                  0
#  volume             150
#  year                 0
#  clean                0
#  title_Arxiv          0
#  pdf_url_Arxiv        0
#  published_Arxiv      0
#  result_Arxiv         0
#  idv1                 0
#  Arxiv_name           0
#  id                   0
#  version              0
#  Anth_name           65
#  dtype: int64)

# %%
papers1 = papers[papers['version']=='1']

# %%
blocks = []
for page in doc.pages():
    b_p = page.get_text('blocks')
    for b in b_p:
        if b[6] == 0: #only text not metadata pictures.
            blocks.append(b[4])

# %%
def get_blocks(doc):
    blocks = []
    for page in doc.pages():
        b_p = page.get_text('blocks')
        for b in b_p:
            if b[6] == 0: #only text not metadata pictures.
                blocks.append(b[4])
    return blocks

# %%
start = time.time()
not_sample, sample = pdf_similarity_loc(embed, papers1,max_iter = 1)
end = time.time()
# print("Time taken:            {:.3f}s".format(end - start))   
print("Time taken:      {:.3f}s".format(end - start), file=sys.stderr)
# Out:
# start with two papers
# Document('pdf Anth/Anth-Utilizing Wordnets for Cognate Detection among Indian Languages.pdf')
# Document('pdf Arxiv/2112.15124v1.Utilizing_Wordnets_for_Cognate_Detection_among_Indian_Languages.pdf')
# Time taken:      13.221s

# %%
start = time.time()
not_sample, sample = pdf_similarity_loc(embed=embed, tab_old = not_sample, result=sample,max_iter = 61, r_state=2)
end = time.time()
# print("Time taken:            {:.3f}s".format(end - start))   
print("Time taken:      {:.3f}s".format(end - start), file=sys.stderr)
# Out:
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Time taken:      679.614s

# %%
len(not_sample)
# Out:
# 0

# %%
sample
# Out:
#     ISBN                                    address  \
# 0    NaN  Online and Punta Cana, Dominican Republic
# 1    NaN                                     Online
# 2    NaN             Punta Cana, Dominican Republic
# 3    NaN                                     Online
# 4    NaN  Online and Punta Cana, Dominican Republic
# ..   ...                                        ...
# 119  NaN                                     Online
# 120  NaN             Punta Cana, Dominican Republic
# 121  NaN  Online and Punta Cana, Dominican Republic
# 122  NaN  Online and Punta Cana, Dominican Republic
# 123  NaN                            Wroclaw, Poland
#
#                                              booktitle  \
# 0    Proceedings of the 2021 Conference on Empirica...
# 1    Proceedings of the 15th International Workshop...
# 2    Proceedings of the Third Workshop on Economics...
# 3    Proceedings of the The 19th Annual Workshop of...
# 4    Proceedings of the 2021 Conference on Empirica...
# ..                                                 ...
# 119  Proceedings of the Seventh Workshop on Noisy U...
# 120  Proceedings of the Natural Legal Language Proc...
# 121  Proceedings of the 2021 Conference on Empirica...
# 122  Proceedings of the 2021 Conference on Empirica...
# 123  Proceedings of the 10th Global Wordnet Conference
#
#                                  doi journal language     month note  number  \
# 0    10.18653/v1/2021.emnlp-main.606     NaN      NaN  November  NaN     NaN
# 1      10.18653/v1/2021.semeval-1.28     NaN      NaN    August  NaN     NaN
# 2        10.18653/v1/2021.econlp-1.7     NaN      NaN  November  NaN     NaN
# 3                                NaN     NaN      NaN  December  NaN     NaN
# 4     10.18653/v1/2021.emnlp-main.28     NaN      NaN  November  NaN     NaN
# ..                               ...     ...      ...       ...  ...     ...
# 119        10.18653/v1/2021.wnut-1.1     NaN      NaN  November  NaN     NaN
# 120        10.18653/v1/2021.nllp-1.6     NaN      NaN  November  NaN     NaN
# 121  10.18653/v1/2021.emnlp-main.521     NaN      NaN  November  NaN     NaN
# 122    10.18653/v1/2021.emnlp-demo.3     NaN      NaN  November  NaN     NaN
# 123                              NaN     NaN      NaN      July  NaN     NaN
#
#           pages  ... Succes   w_Anth  w_Arxiv  pages_Anth  pages_Arxiv cosine  \
# 0    7676--7682  ...    1.0   4435.0   4416.0         7.0          7.0    NaN
# 1      243--248  ...    1.0   3244.0   3291.0         6.0          6.0    NaN
# 2        50--55  ...    1.0   3773.0   3747.0         6.0          6.0    NaN
# 3      158--162  ...    1.0   3266.0   3265.0         5.0          5.0    NaN
# 4      325--344  ...    1.0  11612.0  11570.0        20.0         20.0    NaN
# ..          ...  ...    ...      ...      ...         ...          ...    ...
# 119       1--10  ...    1.0   5292.0   5258.0        10.0         10.0    NaN
# 120      63--75  ...    1.0   7390.0   7361.0        13.0         12.0    NaN
# 121  6475--6490  ...    1.0   8730.0   8692.0        16.0         16.0    NaN
# 122      20--27  ...    1.0   3805.0   3742.0         8.0          7.0    NaN
# 123    404--412  ...    1.0   5103.0   5170.0         9.0         10.0    NaN
#
#     ref_Anth ref_Arxiv   Jaccard cosine_avg
# 0       37.0      32.0  0.985893   0.931972
# 1       28.0      23.0  0.929755   0.804503
# 2       44.0      37.0  0.987896   0.881075
# 3       30.0      30.0  0.954545   0.952199
# 4       92.0      80.0  0.993292   0.982506
# ..       ...       ...       ...        ...
# 119     46.0      36.0  0.992055   0.933479
# 120     65.0      56.0  0.992711   0.962880
# 121     87.0      71.0  0.993588   0.965745
# 122     33.0       0.0  0.985259   0.889308
# 123     38.0      69.0  0.962283   0.892383
#
# [124 rows x 35 columns]

# %%
sample.to_csv('sample1.csv')
not_sample.to_csv('not_sample1.csv')

# %% [markdown]
# # test on random papers

# %%
ran = pd.read_csv('ran_sample.csv').drop('Unnamed: 0', axis =1)

# %%
table_pred = prepare_table(table)
cop = table_pred.copy()
cop = cop.reset_index()
# ran = table_pred.head(10)#['title', 'year', 'month', 'url'] #[5:10]#['title', 'year', 'month', 'url']]
# ran2 = table_pred.tail(10)
ran = cop.loc[:9,['title', 'url']]
ran2 = cop.loc[len(table_pred)-10:len(table_pred),['title_Arxiv', 'pdf_url_Arxiv', 'result_Arxiv']]
ran2 = ran2.reset_index()
random = ran.join(ran2)
# random.loc[[3],['title_Arxiv', 'pdf_url_Arxiv', 'published_Arxiv', 'result_Arxiv']] = ran2

# %%
random
# Out:
#                                                title  \
# 0  Modeling Profanity and Hate Speech in Social M...
# 1  HateBERT: Retraining BERT for Abusive Language...
# 2  Memes in the Wild: Assessing the Generalizabil...
# 3  Measuring and Improving Model-Moderator Collab...
# 4  Improving Counterfactual Generation for Fair H...
# 5  Mitigating Biases in Toxic Language Detection ...
# 6  When the Echo Chamber Shatters: Examining the ...
# 7  Text Simplification for Comprehension-based Qu...
# 8  Detecting Depression in Thai Blog Posts: a Dat...
# 9  Can images help recognize entities? A study of...
#
#                                        url  index  \
# 0   https://aclanthology.org/2021.woah-1.2   8875
# 1   https://aclanthology.org/2021.woah-1.3   8876
# 2   https://aclanthology.org/2021.woah-1.4   8877
# 3   https://aclanthology.org/2021.woah-1.5   8878
# 4  https://aclanthology.org/2021.woah-1.10   8879
# 5  https://aclanthology.org/2021.woah-1.12   8880
# 6  https://aclanthology.org/2021.woah-1.18   8881
# 7   https://aclanthology.org/2021.wnut-1.1   8882
# 8   https://aclanthology.org/2021.wnut-1.3   8883
# 9  https://aclanthology.org/2021.wnut-1.11   8884
#
#                                          title_Arxiv  \
# 0  Overcoming the Curse of Sentence Length for Ne...
# 1  A Novel Two-stage Framework for Extracting Opi...
# 2  Arabic Spelling Correction using Supervised Le...
# 3         Arabizi Detection and Conversion to Arabic
# 4  DiscoTK: Using Discourse Structure for Machine...
# 5  Credibility Adjusted Term Frequency: A Supervi...
# 6  Improving Agreement and Disagreement Identific...
# 7            Finding Eyewitness Tweets During Crises
# 8  Temporal Analysis of Language through Neural L...
# 9           A Deep Architecture for Semantic Parsing
#
#                        pdf_url_Arxiv                       result_Arxiv
# 0   http://arxiv.org/pdf/1409.1257v1   http://arxiv.org/abs/1409.1257v2
# 1  http://arxiv.org/pdf/2101.09743v1  http://arxiv.org/abs/2101.09743v1
# 2   http://arxiv.org/pdf/1409.8309v1   http://arxiv.org/abs/1409.8309v1
# 3   http://arxiv.org/pdf/1306.6755v1   http://arxiv.org/abs/1306.6755v1
# 4  http://arxiv.org/pdf/1911.12547v1  http://arxiv.org/abs/1911.12547v1
# 5   http://arxiv.org/pdf/1405.3518v1   http://arxiv.org/abs/1405.3518v2
# 6  http://arxiv.org/pdf/1606.05706v1  http://arxiv.org/abs/1606.05706v1
# 7   http://arxiv.org/pdf/1403.1773v1   http://arxiv.org/abs/1403.1773v1
# 8   http://arxiv.org/pdf/1405.3515v1   http://arxiv.org/abs/1405.3515v1
# 9   http://arxiv.org/pdf/1404.7296v1   http://arxiv.org/abs/1404.7296v1

# %%
start = time.time()
r_not_sample, r_sample = run(embed, random,max_iter = 10)
end = time.time()
# print("Time taken:            {:.3f}s".format(end - start))   
print("Time taken:      {:.3f}s".format(end - start), file=sys.stderr)
# Out:
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# start with two papers
# Time taken:      280.505s

# %%
r_sample #new 20
# Out:
#                                                title  \
# 4  Improving Counterfactual Generation for Fair H...
# 1  HateBERT: Retraining BERT for Abusive Language...
# 5  Mitigating Biases in Toxic Language Detection ...
# 0  Modeling Profanity and Hate Speech in Social M...
# 7  Text Simplification for Comprehension-based Qu...
# 2  Memes in the Wild: Assessing the Generalizabil...
# 3  Measuring and Improving Model-Moderator Collab...
# 6  When the Echo Chamber Shatters: Examining the ...
# 9  Can images help recognize entities? A study of...
# 8  Detecting Depression in Thai Blog Posts: a Dat...
#
#                                        url  index  \
# 4  https://aclanthology.org/2021.woah-1.10   8879
# 1   https://aclanthology.org/2021.woah-1.3   8876
# 5  https://aclanthology.org/2021.woah-1.12   8880
# 0   https://aclanthology.org/2021.woah-1.2   8875
# 7   https://aclanthology.org/2021.wnut-1.1   8882
# 2   https://aclanthology.org/2021.woah-1.4   8877
# 3   https://aclanthology.org/2021.woah-1.5   8878
# 6  https://aclanthology.org/2021.woah-1.18   8881
# 9  https://aclanthology.org/2021.wnut-1.11   8884
# 8   https://aclanthology.org/2021.wnut-1.3   8883
#
#                                          title_Arxiv  \
# 4  DiscoTK: Using Discourse Structure for Machine...
# 1  A Novel Two-stage Framework for Extracting Opi...
# 5  Credibility Adjusted Term Frequency: A Supervi...
# 0  Overcoming the Curse of Sentence Length for Ne...
# 7            Finding Eyewitness Tweets During Crises
# 2  Arabic Spelling Correction using Supervised Le...
# 3         Arabizi Detection and Conversion to Arabic
# 6  Improving Agreement and Disagreement Identific...
# 9           A Deep Architecture for Semantic Parsing
# 8  Temporal Analysis of Language through Neural L...
#
#                        pdf_url_Arxiv                       result_Arxiv  \
# 4  http://arxiv.org/pdf/1911.12547v1  http://arxiv.org/abs/1911.12547v1
# 1  http://arxiv.org/pdf/2101.09743v1  http://arxiv.org/abs/2101.09743v1
# 5   http://arxiv.org/pdf/1405.3518v1   http://arxiv.org/abs/1405.3518v2
# 0   http://arxiv.org/pdf/1409.1257v1   http://arxiv.org/abs/1409.1257v2
# 7   http://arxiv.org/pdf/1403.1773v1   http://arxiv.org/abs/1403.1773v1
# 2   http://arxiv.org/pdf/1409.8309v1   http://arxiv.org/abs/1409.8309v1
# 3   http://arxiv.org/pdf/1306.6755v1   http://arxiv.org/abs/1306.6755v1
# 6  http://arxiv.org/pdf/1606.05706v1  http://arxiv.org/abs/1606.05706v1
# 9   http://arxiv.org/pdf/1404.7296v1   http://arxiv.org/abs/1404.7296v1
# 8   http://arxiv.org/pdf/1405.3515v1   http://arxiv.org/abs/1405.3515v1
#
#    Succes   w_Anth  w_Arxiv  w_both  pages_Anth  pages_Arxiv    cosine  \
# 4     1.0   5436.0   4296.0     NaN        10.0          8.0  0.490809
# 1     1.0   4919.0   5728.0     NaN         9.0          9.0  0.492599
# 5     1.0   4248.0   2542.0     NaN         7.0          5.0  0.393532
# 0     1.0   7037.0   4359.0     NaN        11.0          7.0  0.501211
# 7     1.0   5292.0   6346.0     NaN        10.0         11.0  0.529852
# 2     1.0   4865.0   3723.0     NaN        10.0          6.0  0.378114
# 3     1.0  10061.0   4631.0     NaN        18.0          8.0  0.450464
# 6     1.0   8666.0   6637.0     NaN        15.0         10.0  0.521938
# 9     1.0   6047.0   3070.0     NaN        10.0          6.0  0.478675
# 8     1.0   3460.0   2732.0     NaN         6.0          5.0  0.326489
#
#    len_blocks  len_Anth  len_Arxiv  len_both  ref_Anth  ref_Arxiv   Jaccard
# 4         NaN       NaN        NaN       NaN      75.0       22.0  0.095070
# 1         NaN       NaN        NaN       NaN      65.0       26.0  0.106205
# 5         NaN       NaN        NaN       NaN      36.0       22.0  0.096110
# 0         NaN       NaN        NaN       NaN      28.0       57.0  0.105679
# 7         NaN       NaN        NaN       NaN      40.0       23.0  0.115042
# 2         NaN       NaN        NaN       NaN      87.0       16.0  0.104698
# 3         NaN       NaN        NaN       NaN     405.0        3.0  0.097291
# 6         NaN       NaN        NaN       NaN      78.0       35.0  0.114820
# 9         NaN       NaN        NaN       NaN      27.0       24.0  0.120555
# 8         NaN       NaN        NaN       NaN      37.0       17.0  0.110707
